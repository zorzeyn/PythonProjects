# %% [markdown]
# # **Greece: A Mediterranean Gem** 🌍
#
# ![Greece Image](https://upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Greece.svg/320px-Flag_of_Greece.svg.png)
#
# ---
#
# ## **1. General Information**
#
# - **Official Name**: Hellenic Republic
# - **Capital**: Athens
# - **Area**: *131,957 km²*
# - **Population**: **10.72 million** (2023)
#
# ---
#
# ## **2. Government**
# Greece is a **parliamentary republic**, with three main branches:
#
# - **Executive Branch**:
#     - President of the Republic (Head of State)
#     - Prime Minister (Head of Government)
# - **Legislative Branch**:
#     - Unicameral parliament (*Vouli ton Ellinon*) consisting of 300 members.
# - **Judicial Branch**:
#     - Independent courts including the **Areopagus** and **Council of State**.
#
# ---
#
# ## **3. Famous Celebrities** 🇬🇷
# - **Aristotle** *(Philosopher)*
# - **Maria Callas** *(Opera Singer)*
# - **Giorgos Lanthimos** *(Film Director)*
# - **Giannis Antetokounmpo** *(NBA Player)*
#
# ---
#
# ## **4. Cultural and Natural Attractions**
# Here are some of the most important **cultural** and **natural** attractions in Greece:
#
# ### **A. Cultural Attractions**
# 1. **Acropolis of Athens**:
#    _A UNESCO World Heritage site, home to the Parthenon._
# 2. **Delphi**:
#    _Ancient sanctuary, home to the oracle of Apollo._
# 3. **Knossos**:
#    _The largest Bronze Age archaeological site on Crete._
#
# ### **B. Natural Attractions**
# - **Meteora**:
#   _Monasteries built on top of towering rock formations._
# - **Santorini**:
#   _A volcanic island known for its stunning sunsets and blue-domed buildings._
#
# ---
#
# ## **5. Greece's Flag** 🇬🇷
#
# The Greek flag consists of **nine alternating blue and white horizontal stripes** with a white cross on a blue square at the top-left corner. The cross represents the Greek Orthodox Church.
#
# ### **Flag Using SVG**
# ```html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 16 10" width="320" height="200">
#   <rect width="16" height="10" fill="#0d5eaf"/>
#   <rect y="1" width="16" height="1" fill="#fff"/>
#   <rect y="3" width="16" height="1" fill="#fff"/>
#   <rect y="5" width="16" height="1" fill="#fff"/>
#   <rect y="7" width="16" height="1" fill="#fff"/>
#   <rect y="9" width="16" height="1" fill="#fff"/>
#   <rect x="5" y="0" width="1" height="10" fill="#fff"/>
#   <rect x="0" y="0" width="5" height="5" fill="#0d5eaf"/>
#   <rect x="1" y="2" width="3" height="1" fill="#fff"/>
#   <rect x="2" y="1" width="1" height="3" fill="#fff"/>
# </svg>
